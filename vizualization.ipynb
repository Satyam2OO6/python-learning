# %%
from bokhe.plotting import figure
from bokhe import output_files,show

x=[1,2,3,4,5]
y=[6,7,8,9,10]

output_files("line.html")
f=figure()
f.line(x,y)
show(f)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from bokhe.plotting import figure
#       2 from bokhe import output_files,show
#       4 x=[1,2,3,4,5]
#
# ModuleNotFoundError: No module named 'bokhe'
